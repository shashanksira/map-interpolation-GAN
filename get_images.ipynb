# %%
import requests
from PIL import Image
from io import BytesIO
import pandas as pd
from pathlib import Path


API_KEY = 'your api key here'

dLat, dLong = 0.010122000000002629, 0.013259999999988281

df = pd.read_excel('Cities500.xlsx')

no_of_cities = df.count()[0]

image_name_list = []
image_city = []
image_state = []
image_latitude = []
image_longitude = []

df3 = pd.DataFrame()

df3['Image Name'] = image_name_list
df3['City'] = image_city
df3['State'] = image_state
df3['Latitude'] = image_latitude
df3['Longitude'] = image_longitude

# check if the file exists before creating new one
my_file = Path('ImageDetails.csv')
if not(my_file.is_file()):
    df3.to_csv('ImageDetails.csv', header=True, mode='a', index=False)


for city_no in range(no_of_cities):
    
    print("-------------------------- started city = ",city_no)

    image_count = 0

    scale = df.Scale[city_no]
    Lat0 = df.Latitude[city_no]
    Long0 = df.Longitude[city_no]
    LatLong0 = str(Lat0) + ','+str(Long0)

    Lat1 = Lat0 + scale*dLat
    Long1 = Long0 - scale*dLong
    LatLong1 = str(Lat1) + ','+str(Long1)

    for i in range(int(scale+1)):
        for j in range(int(scale+1)):

            Lati = Lat1 - i*dLat
            Longi = Long1 + j*dLong
            LatLongi = str(Lati) + ','+str(Longi)

            image_name_list.append('city_no_'+ str(city_no) +'_image_number_'+str(image_count))
            image_count = image_count + 1
            image_city.append(df.City[city_no])
            image_state.append(df.State[city_no])
            image_latitude.append(Lati)
            image_longitude.append(Longi)

            ##############################################################################################

            roadmap_url = 'https://maps.googleapis.com/maps/api/staticmap?zoom=16&size=620x640&scale=2&maptype=roadmap&center='+LatLongi+'&key='+API_KEY

            response = requests.get(roadmap_url)            
            im = Image.open(BytesIO(response.content))
            image_name = 'city_no_'+ str(city_no) +'_roadmap_image_'+str(image_count)
            im.save('roadmap-images/'+image_name+'.png')

            ##############################################################################################

            satellite_url = 'https://maps.googleapis.com/maps/api/staticmap?zoom=16&size=620x640&scale=2&maptype=satellite&center='+LatLongi+'&key='+API_KEY

            response = requests.get(satellite_url)
            im = Image.open(BytesIO(response.content))
            image_name = 'city_no_'+ str(city_no) +'_satellite_image_'+str(image_count)
            im.save('satellite-images/'+image_name+'.png')
            
            print("city_no = ", city_no," image_no = ", image_count)
            
    print("-------------------------- finished city = ",city_no)


df3 = pd.DataFrame()

df3['Image Name'] = image_name_list
df3['City'] = image_city
df3['State'] = image_state
df3['Latitude'] = image_latitude
df3['Longitude'] = image_longitude
df3.to_csv('ImageDetails.csv', header=True, mode='a', index=False)
# Out:
# ('city_no = ', 200, ' image_no = ', 1)
# ('city_no = ', 200, ' image_no = ', 2)
# ('city_no = ', 200, ' image_no = ', 3)
# ('city_no = ', 200, ' image_no = ', 4)
# ('city_no = ', 200, ' image_no = ', 5)
# ('city_no = ', 200, ' image_no = ', 6)
# ('city_no = ', 200, ' image_no = ', 7)
# ('city_no = ', 200, ' image_no = ', 8)
# ('city_no = ', 200, ' image_no = ', 9)
# ('city_no = ', 200, ' image_no = ', 10)
# ('city_no = ', 200, ' image_no = ', 11)
# ('city_no = ', 200, ' image_no = ', 12)
# ('city_no = ', 200, ' image_no = ', 13)
# ('city_no = ', 200, ' image_no = ', 14)
# ('city_no = ', 200, ' image_no = ', 15)
# ('city_no = ', 200, ' image_no = ', 16)
# ('city_no = ', 200, ' image_no = ', 17)
# ('city_no = ', 200, ' image_no = ', 18)
# ('city_no = ', 200, ' image_no = ', 19)
# ('city_no = ', 200, ' image_no = ', 20)
# ('city_no = ', 200, ' image_no = ', 21)
# ('city_no = ', 200, ' image_no = ', 22)
# ('city_no = ', 200, ' image_no = ', 23)
# ('city_no = ', 200, ' image_no = ', 24)
# ('city_no = ', 200, ' image_no = ', 25)
# ('city_no = ', 200, ' image_no = ', 26)
# ('city_no = ', 200, ' image_no = ', 27)
# ('city_no = ', 200, ' image_no = ', 28)
# ('city_no = ', 200, ' image_no = ', 29)
# ('city_no = ', 200, ' image_no = ', 30)
# ('city_no = ', 200, ' image_no = ', 31)
# ('city_no = ', 200, ' image_no = ', 32)
# ('city_no = ', 200, ' image_no = ', 33)
# ('city_no = ', 200, ' image_no = ', 34)
# ('city_no = ', 200, ' image_no = ', 35)
# ('city_no = ', 200, ' image_no = ', 36)
# ('city_no = ', 200, ' image_no = ', 37)
# ('city_no = ', 200, ' image_no = ', 38)
# ('city_no = ', 200, ' image_no = ', 39)
# ('city_no = ', 200, ' image_no = ', 40)
# ('city_no = ', 200, ' image_no = ', 41)
# ('city_no = ', 200, ' image_no = ', 42)
# ('city_no = ', 200, ' image_no = ', 43)
# ('city_no = ', 200, ' image_no = ', 44)
# ('city_no = ', 200, ' image_no = ', 45)
# ('city_no = ', 200, ' image_no = ', 46)
# ('city_no = ', 200, ' image_no = ', 47)
# ('city_no = ', 200, ' image_no = ', 48)
# ('city_no = ', 200, ' image_no = ', 49)
# ('city_no = ', 200, ' image_no = ', 50)
# ('city_no = ', 200, ' image_no = ', 51)
# ('city_no = ', 200, ' image_no = ', 52)
# ('city_no = ', 200, ' image_no = ', 53)
# ('city_no = ', 200, ' image_no = ', 54)
# ('city_no = ', 200, ' image_no = ', 55)
# ('city_no = ', 200, ' image_no = ', 56)
# ('city_no = ', 200, ' image_no = ', 57)
# ('city_no = ', 200, ' image_no = ', 58)
# ('city_no = ', 200, ' image_no = ', 59)
# ('city_no = ', 200, ' image_no = ', 60)
# ('city_no = ', 200, ' image_no = ', 61)
# ('city_no = ', 200, ' image_no = ', 62)
# ('city_no = ', 200, ' image_no = ', 63)
# ('city_no = ', 200, ' image_no = ', 64)
# ('city_no = ', 200, ' image_no = ', 65)
# ('city_no = ', 200, ' image_no = ', 66)
# ('city_no = ', 200, ' image_no = ', 67)
# ('city_no = ', 200, ' image_no = ', 68)
# ('city_no = ', 200, ' image_no = ', 69)
# ('city_no = ', 200, ' image_no = ', 70)
# ('city_no = ', 200, ' image_no = ', 71)
# ('city_no = ', 200, ' image_no = ', 72)
# ('city_no = ', 200, ' image_no = ', 73)
# ('city_no = ', 200, ' image_no = ', 74)
# ('city_no = ', 200, ' image_no = ', 75)
# ('city_no = ', 200, ' image_no = ', 76)
# ('city_no = ', 200, ' image_no = ', 77)
# ('city_no = ', 200, ' image_no = ', 78)
# ('city_no = ', 200, ' image_no = ', 79)
# ('city_no = ', 200, ' image_no = ', 80)
# ('city_no = ', 200, ' image_no = ', 81)
